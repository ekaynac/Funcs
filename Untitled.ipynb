# %%
import eda
import pandas as pd
import numpy as np
# Out:
# Bad key "text.kerning_factor" on line 4 in
# C:\Users\enes_\anaconda3\envs\tensorflow-gpu\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test_patch.mplstyle.
# You probably need to get an updated matplotlibrc file from
# https://github.com/matplotlib/matplotlib/blob/v3.1.3/matplotlibrc.template
# or from the matplotlib source distribution

# %%
df = pd.read_csv("train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                               Heikkinen, Miss. Laina  female 26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                             Allen, Mr. William Henry    male 35.00      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
eda.miss.check(df,check_type="sd")
# Out:
# Wrong 'check_type'

# %%
eda.miss.check(df)
# Out:
# PassengerId    0.00
# Survived       0.00
# Pclass         0.00
# Name           0.00
# Sex            0.00
# Age           19.87
# SibSp          0.00
# Parch          0.00
# Ticket         0.00
# Fare           0.00
# Cabin         77.10
# Embarked       0.22
# dtype: float64

# %%
x = eda.miss.fill(df)

# %%
eda.miss.check(x)
# Out:
# PassengerId    0.00
# Survived       0.00
# Pclass         0.00
# Name           0.00
# Sex            0.00
# Age            0.00
# SibSp          0.00
# Parch          0.00
# Ticket         0.00
# Fare           0.00
# Cabin         74.09
# Embarked       0.28
# dtype: float64

# %%
eda.meet.hello(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
#
# is there any missing value: True
# row count: 891
# feature count: 12
# object feature count: 5
#        PassengerId  Survived  Pclass    Age  SibSp  Parch   Fare
# ...

# %%
df[df.columns[df.dtypes != object]]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch  Fare
# 0              1         0       3 22.00      1      0  7.25
# 1              2         1       1 38.00      1      0 71.28
# 2              3         1       3 26.00      0      0  7.92
# 3              4         1       1 35.00      1      0 53.10
# 4              5         0       3 35.00      0      0  8.05
# ..           ...       ...     ...   ...    ...    ...   ...
# 886          887         0       2 27.00      0      0 13.00
# 887          888         1       1 19.00      0      0 30.00
# 888          889         0       3   nan      1      2 23.45
# 889          890         1       1 26.00      0      0 30.00
# 890          891         0       3 32.00      0      0  7.75
#
# [891 rows x 7 columns]

# %%
pd.DataFrame(df.corr()["PassengerId"]).sort_values(by="PassengerId",ascending=False)
# Out:
#              PassengerId
# PassengerId         1.00
# Age                 0.04
# Fare                0.01
# Parch              -0.00
# Survived           -0.01
# Pclass             -0.04
# SibSp              -0.06

# %%
eda.meet.plots(df)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0           0.00         0    3.38
# 1           0.90         1    0.00
# 2           1.66         1    3.38
# 3           2.36         1    0.00
# 4           3.01         0    3.38
# ..           ...       ...     ...
# 886       172.69         0    1.36
# 887       172.83         1    0.00
# 888       172.97         0    3.38
# 889       173.11         1    0.00
# 890       173.25         0    3.38
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male 22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female 38.00      1
# 2                               Heikkinen, Miss. Laina  female 26.00      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female 35.00      1
# 4                             Allen, Mr. William Henry    male 35.00      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Survived"]
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
features_to_plot =df.columns[df.dtypes != object]
positive_features = list()
non_negative_features = list()

# %%
        for feature in features_to_plot:
            if (df[feature] > 0).all():
                positive_features.append(feature)
            elif (df[feature] >=0).all():
                non_negative_features.append(feature)

# %%
positive_features
# Out:
# []

# %%
non_negative_features
# Out:
# ['PassengerId', 'Survived', 'Pclass', 'SibSp', 'Parch', 'Fare']

# %%
eda.meet.corr(df,"Survived",scatter=True)
# Out:
#              Survived
# Survived         1.00
# Fare             0.26
# Parch            0.08
# PassengerId     -0.00
# SibSp           -0.04
# Age             -0.08
# Pclass          -0.34
